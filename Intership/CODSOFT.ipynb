# %% [markdown]
# 1. LAIBA MAZHAR
# 2. CODSOFT- Python Intership
# 3. 4 Questions Attempted

# %%
# Laiba Mazhar
# NUCES,FAST
print("\t\t\t\t\t\t________________________")
print("\t\t\t\t\t\t|  Laiba's Calculator  |")
print("\t\t\t\t\t\t|______________________|")
print("\n")
print("___________________")
print("|   1. Add        |")
print("|_________________|")
print("|   2. Subtract   |")
print("|_________________|")
print("|   3. Multiply   |")
print("|_________________|")
print("|   4. Divide     |")
print("|_________________|")
print("\n\n")
num1 = float(input("Enter first number : "))
num2 = float(input("Enter second number: "))
print("\n\n")
operation = input("Enter operation (1/2/3/4): ")
print("\n\n")
if operation == '1':
    result = num1 + num2
elif operation == '2':
    result = num1 - num2
elif operation == '3':
    result = num1 * num2
elif operation == '4':
    if num2 != 0:
        result = num1 / num2
    else:
        print("Error: Cannot divide by zero.")
        exit()
else:
    print("Invalid operation.")
    exit()

print("Result  =  {}".format(result))
# Out:
# 						________________________
# 						|  Laiba's Calculator  |
# 						|______________________|
#
#
# ___________________
# |   1. Add        |
# |_________________|
# |   2. Subtract   |
# |_________________|
# |   3. Multiply   |
# |_________________|
# |   4. Divide     |
# |_________________|
#
#
#
# Enter first number : 20
# Enter second number: 21
#
#
#
# Enter operation (1/2/3/4): 3
#
#
#
# Result  =  420.0

# %%
# Laiba Mazhar
# NUCES,FAST

import random
import string
print("\t\t\t\t\t\t________________________________")
print("\t\t\t\t\t\t|  Laiba's Password Generator  |")
print("\t\t\t\t\t\t|______________________________|")
print("\n")
while True:
    length = input("Enter the length of the password: ")
    if length.isdigit() and int(length) > 0:
        length = int(length)
        break
    else:
        print("Please enter a valid positive integer.")


characters = string.ascii_letters + string.digits + string.punctuation
pwd = ""
for i in range(length):
    pwd += random.choice(characters)

print("\n\n")
print("\t\t\t\t\t\t__________________________")
print("\t\t\t\t\t\t|   Generated Password   |")
print("\t\t\t\t\t\t|________________________|")
print("\n")
pwd
# Out:
# 						________________________________
# 						|  Laiba's Password Generator  |
# 						|______________________________|
#
#
# Enter the length of the password: 21
#
#
#
# 						__________________________
# 						|   Generated Password   |
# 						|________________________|
# "i[xo!'zrFVrd/k,7l/bwX"

# %%
# Laiba Mazhar
# NUCES,FAST

laiba_list = []
while True:
    print("\n")
    print("\t\t\t\t\t_______________________________________")
    print("\t\t\t\t\t|  Laiba's Contact Management System  |")
    print("\t\t\t\t\t|_____________________________________|")
    print("_______________________")
    print("|  1. Add Contact     |")
    print("|  2. View Contacts   |")
    print("|  3. Search Contact  |")
    print("|  4. Update Contact  |")
    print("|  5. Delete Contact  |")
    print("|  6. Exit            |")
    print("|_____________________|")
    print("\n")
    choice = input("Enter your choice (1/2/3/4/5/6): ")
    print("\n")
    if choice == '1':
        name = input("Enter contact name: ")
        print("\n")
        phone = input("Enter phone number: ")
        print("\n")
        email = input("Enter email address: ")
        print("\n")
        address = input("Enter address: ")
        print("\n")
        new_contact = {'name': name, 'phone': phone, 'email': email, 'address': address}
        laiba_list.append(new_contact)
        print("\t\t\t\t\tContact '{}' added successfully!".format(name))

    elif choice == '2':
        if not laiba_list:
            print("No contacts found.")
        else:
            print("\t\t\t\t\t\t__________________")
            print("\t\t\t\t\t\t|  Contact List  |")
            print("\t\t\t\t\t\t|________________|")
            print("\n")
            for i in laiba_list:
                print("Name: {}, Phone No: {}".format(i['name'], i['phone']))
                print("\n")

    elif choice == '3':
        search = input("Enter name or phone number to search: ")
        print("\n")
        matching_contacts = [
            contact for contact in laiba_list
            if "{}".format(search.lower()) in "{}".format(contact['name'].lower()) or search in contact['phone']
        ]

        if not matching_contacts:
            print("No matching contacts found.")
        else:
            print("\t\t\t\t\t\t_______________________")
            print("\t\t\t\t\t\t|  Matching Contacts  |")
            print("\t\t\t\t\t\t|_____________________|")
            print("\n")
            for i in matching_contacts:
                print("Name: {}, Phone: {}".format(i['name'], i['phone']))

    elif choice == '4':
        name = input("Enter the name of the contact to update: ")
        print("\n")
        for i in laiba_list:
            if i['name'].lower() == name.lower():
                i['phone'] = input("Enter the new phone number: ")
                print("\n")
                i['email'] = input("Enter the new email address: ")
                print("\n")
                i['address'] = input("Enter the new address: ")
                print("\n")
                print("\t\t\t\t\tContact '{}' updated successfully!".format(name))
                break
        else:
            print("Contact '{}' not found.".format(name))

    elif choice == '5':
        name = input("Enter the name of the contact to delete: ")
        print("\n")
        for i in laiba_list:
            if i['name'].lower() == name.lower():
                laiba_list.remove(i)
                print("\t\t\t\t\tContact '{}' deleted successfully!".format(name))
                break
        else:
            print("Contact '{}' not found.".format(name))

    elif choice == '6':
        print("\t\t\t\t\tExiting Laiba's Contact Management System!")
        break

    else:
        print("\t\t\t\t\tWrong choice! ")
        print("\n")
# Out:
# 					_______________________________________
# 					|  Laiba's Contact Management System  |
# 					|_____________________________________|
# _______________________
# |  1. Add Contact     |
# |  2. View Contacts   |
# |  3. Search Contact  |
# |  4. Update Contact  |
# |  5. Delete Contact  |
# |  6. Exit            |
# |_____________________|
#
#
# Enter your choice (1/2/3/4/5/6): 1
#
#
# Enter contact name: Shubu
#
#
# Enter phone number: 0348764536
#
#
# Enter email address: shubuimran@gmail.com
#
#
# Enter address: House 789, Street 4, G13/4
#
#
# 					Contact 'Shubu' added successfully!
#
#
# 					_______________________________________
# 					|  Laiba's Contact Management System  |
# 					|_____________________________________|
# _______________________
# |  1. Add Contact     |
# |  2. View Contacts   |
# |  3. Search Contact  |
# |  4. Update Contact  |
# |  5. Delete Contact  |
# |  6. Exit            |
# |_____________________|
#
#
# Enter your choice (1/2/3/4/5/6): 1
#
#
# Enter contact name: Bushr
#
#
# Enter phone number: 03235345768
#
#
# Enter email address: bushraakhtar@hotmail.com
#
#
# Enter address: House 43, street 75, Margalla town
#
#
# 					Contact 'Bushr' added successfully!
#
#
# 					_______________________________________
# 					|  Laiba's Contact Management System  |
# 					|_____________________________________|
# _______________________
# |  1. Add Contact     |
# |  2. View Contacts   |
# |  3. Search Contact  |
# |  4. Update Contact  |
# |  5. Delete Contact  |
# |  6. Exit            |
# |_____________________|
#
#
# Enter your choice (1/2/3/4/5/6): 2
#
#
# 						__________________
# 						|  Contact List  |
# 						|________________|
#
#
# Name: Shubu, Phone No: 0348764536
#
#
# Name: Bushr, Phone No: 03235345768
#
#
#
#
# 					_______________________________________
# 					|  Laiba's Contact Management System  |
# 					|_____________________________________|
# _______________________
# |  1. Add Contact     |
# |  2. View Contacts   |
# |  3. Search Contact  |
# |  4. Update Contact  |
# |  5. Delete Contact  |
# |  6. Exit            |
# |_____________________|
#
#
# Enter your choice (1/2/3/4/5/6): 3
#
#
# Enter name or phone number to search: Shubu
#
#
# 						_______________________
# 						|  Matching Contacts  |
# 						|_____________________|
#
#
# Name: Shubu, Phone: 0348764536
#
#
# 					_______________________________________
# 					|  Laiba's Contact Management System  |
# 					|_____________________________________|
# _______________________
# |  1. Add Contact     |
# |  2. View Contacts   |
# |  3. Search Contact  |
# |  4. Update Contact  |
# |  5. Delete Contact  |
# |  6. Exit            |
# |_____________________|
#
#
# Enter your choice (1/2/3/4/5/6): 4
#
#
# Enter the name of the contact to update: Shubu
#
#
# Enter the new phone number: 031282721923
#
#
# Enter the new email address: laibaimran@gmail.com
#
#
# Enter the new address: house 54, street 1, G13/1
#
#
# 					Contact 'Shubu' updated successfully!
#
#
# 					_______________________________________
# 					|  Laiba's Contact Management System  |
# 					|_____________________________________|
# _______________________
# |  1. Add Contact     |
# |  2. View Contacts   |
# |  3. Search Contact  |
# |  4. Update Contact  |
# |  5. Delete Contact  |
# |  6. Exit            |
# |_____________________|
#
#
# Enter your choice (1/2/3/4/5/6): 3
#
#
# Enter name or phone number to search: Shubu
#
#
# 						_______________________
# 						|  Matching Contacts  |
# 						|_____________________|
#
#
# Name: Shubu, Phone: 031282721923
#
#
# 					_______________________________________
# 					|  Laiba's Contact Management System  |
# 					|_____________________________________|
# _______________________
# |  1. Add Contact     |
# |  2. View Contacts   |
# |  3. Search Contact  |
# |  4. Update Contact  |
# |  5. Delete Contact  |
# |  6. Exit            |
# |_____________________|
#
#
# Enter your choice (1/2/3/4/5/6): 5
#
#
# Enter the name of the contact to delete: Shubu
#
#
# 					Contact 'Shubu' deleted successfully!
#
#
# 					_______________________________________
# 					|  Laiba's Contact Management System  |
# 					|_____________________________________|
# _______________________
# |  1. Add Contact     |
# |  2. View Contacts   |
# |  3. Search Contact  |
# |  4. Update Contact  |
# |  5. Delete Contact  |
# |  6. Exit            |
# |_____________________|
#
#
# Enter your choice (1/2/3/4/5/6): 2
#
#
# 						__________________
# 						|  Contact List  |
# 						|________________|
#
#
# Name: Bushr, Phone No: 03235345768
#
#
#
#
# 					_______________________________________
# 					|  Laiba's Contact Management System  |
# 					|_____________________________________|
# _______________________
# |  1. Add Contact     |
# |  2. View Contacts   |
# |  3. Search Contact  |
# |  4. Update Contact  |
# |  5. Delete Contact  |
# |  6. Exit            |
# |_____________________|
#
#
# Enter your choice (1/2/3/4/5/6): 6
#
#
# 					Exiting Laiba's Contact Management System!

# %%
# Laiba Mazhar
# NUCES,FAST

import random

print("\n")
print("\t\t\t\t\t_____________________________")
print("\t\t\t\t\t|  Rock-Paper-Scissors Game |")
print("\t\t\t\t\t|___________________________|")

me = 0
pc = 0
while True:
    print("\n")
    print("-------------------------------------------------------------------------------------------------------")
    print("_____________________")
    print("|  Select from List |")
    print("|    1. Rock        |")
    print("|    2. Paper       |")
    print("|    3. Scissors    |")
    print("|    4. Exit        |")
    print("|___________________|")
    print("\n")

    mine = input("Enter: ")
    print("-------------------------------------------------------------------------------------------------------")
    if mine.isdigit():
        if 1 <= int(mine) <= 3:
            user_choice_index = int(mine) - 1
            list1 = ['rock', 'paper', 'scissors']
            me_choices = list1[user_choice_index]

            pc_choices = random.choice(['rock', 'paper', 'scissors'])

            if me_choices == pc_choices:

                final = "It is a tie :)"

            elif (me_choices == 'rock' and pc_choices == 'scissors') or \
                 (me_choices == 'scissors' and pc_choices == 'paper') or \
                 (me_choices == 'paper' and pc_choices == 'rock'):
                final = "Me win ! "
                me += 10

            else:
                print("\n")
                final = "Me lost :( "
                pc += 10

            print("My choice  : {}".format(me_choices))
            print("\n")
            print("Pc's choice: {}".format(pc_choices))
            print("\n")
            print("-------------------------------------------------------------------------------------------------------")
            print("\n")
            print(final)
            print("\n")
            print("-------------------------------------------------------------------------------------------------------")
            print("\t\t\t\t\t___________")
            print("\t\t\t\t\t|  Scores |")
            print("\t\t\t\t\t|_________|")
            print("Mine: {}".format(me))
            print("\n")
            print("PC  : {}".format(pc))
            print("\n")
            print("-------------------------------------------------------------------------------------------------------")
            laiba_again = input("Do you want to play again?").lower()
            if laiba_again != 'yes' and laiba_again != 'y':
                print("\n")
                print("Bye Bye :) !")
                break
        elif mine == '4':
            print("\n")
            print("Bye Bye!")
            break
        else:
            print("Please enter 1, 2, 3, or 4.")
    else:
        print("Please enter a numerical value.")
# Out:
# 					_____________________________
# 					|  Rock-Paper-Scissors Game |
# 					|___________________________|
#
#
# -------------------------------------------------------------------------------------------------------
# _____________________
# |  Select from List |
# |    1. Rock        |
# |    2. Paper       |
# |    3. Scissors    |
# |    4. Exit        |
# |___________________|
#
#
# Enter: 1
# -------------------------------------------------------------------------------------------------------
#
#
# My choice  : rock
#
#
# Pc's choice: paper
#
#
# -------------------------------------------------------------------------------------------------------
#
#
# Me lost :(
#
#
# -------------------------------------------------------------------------------------------------------
# 					___________
# 					|  Scores |
# 					|_________|
# Mine: 0
#
#
# PC  : 10
#
#
# -------------------------------------------------------------------------------------------------------
# Do you want to play again?y
#
#
# -------------------------------------------------------------------------------------------------------
# _____________________
# |  Select from List |
# |    1. Rock        |
# |    2. Paper       |
# |    3. Scissors    |
# |    4. Exit        |
# |___________________|
#
#
# Enter: 3
# -------------------------------------------------------------------------------------------------------
#
#
# My choice  : scissors
#
#
# Pc's choice: rock
#
#
# -------------------------------------------------------------------------------------------------------
#
#
# Me lost :(
#
#
# -------------------------------------------------------------------------------------------------------
# 					___________
# 					|  Scores |
# 					|_________|
# Mine: 0
#
#
# PC  : 20
#
#
# -------------------------------------------------------------------------------------------------------
# Do you want to play again?YES
#
#
# -------------------------------------------------------------------------------------------------------
# _____________________
# |  Select from List |
# |    1. Rock        |
# |    2. Paper       |
# |    3. Scissors    |
# |    4. Exit        |
# |___________________|
#
#
# Enter: 2
# -------------------------------------------------------------------------------------------------------
#
#
# My choice  : paper
#
#
# Pc's choice: scissors
#
#
# -------------------------------------------------------------------------------------------------------
#
#
# Me lost :(
#
#
# -------------------------------------------------------------------------------------------------------
# 					___________
# 					|  Scores |
# 					|_________|
# Mine: 0
#
#
# PC  : 30
#
#
# -------------------------------------------------------------------------------------------------------
# Do you want to play again?y
#
#
# -------------------------------------------------------------------------------------------------------
# _____________________
# |  Select from List |
# |    1. Rock        |
# |    2. Paper       |
# |    3. Scissors    |
# |    4. Exit        |
# |___________________|
#
#
# Enter: 1
# -------------------------------------------------------------------------------------------------------
# My choice  : rock
#
#
# Pc's choice: rock
#
#
# -------------------------------------------------------------------------------------------------------
#
#
# It is a tie :)
#
#
# -------------------------------------------------------------------------------------------------------
# 					___________
# 					|  Scores |
# 					|_________|
# Mine: 0
#
#
# PC  : 30
#
#
# -------------------------------------------------------------------------------------------------------
# Do you want to play again?y
#
#
# -------------------------------------------------------------------------------------------------------
# _____________________
# |  Select from List |
# |    1. Rock        |
# |    2. Paper       |
# |    3. Scissors    |
# |    4. Exit        |
# |___________________|
#
#
# Enter: 3
# -------------------------------------------------------------------------------------------------------
# My choice  : scissors
#
#
# Pc's choice: paper
#
#
# -------------------------------------------------------------------------------------------------------
#
#
# Me win !
#
#
# -------------------------------------------------------------------------------------------------------
# 					___________
# 					|  Scores |
# 					|_________|
# Mine: 10
#
#
# PC  : 30
#
#
# -------------------------------------------------------------------------------------------------------
# Do you want to play again?n
#
#
# Bye Bye :) !
